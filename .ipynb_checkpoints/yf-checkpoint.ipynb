# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from pandas_datareader import data as pdr
import datetime
import numpy as np
import scipy.stats as scs
import scipy.optimize as sco

# %%
name = input('Stock abb ')
# Out:
# Stock abb MS

# %%
all_stocks = []

# %%
all_stocks.append(name)

# %%
stock = yf.Ticker(name)
bs = stock.quarterly_balance_sheet
cf = stock.quarterly_cashflow
i_s = stock.quarterly_financials

# %%
stock.info
# Out:
# {'zip': '10036',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 74000,
#  'longBusinessSummary': 'Morgan Stanley, a financial holding company, provides various financial products and services to corporations, governments, financial institutions, and individuals in the Americas, Europe, the Middle East, Africa, and Asia. The company operates through Institutional Securities, Wealth Management, and Investment Management segments. The Institutional Securities segment offers capital raising and financial advisory services, including services related to the underwriting of debt, equity, and other securities, as well as advice on mergers and acquisitions, restructurings, real estate, and project finance. This segment also provides sales and trading services, such as sales, financing, prime brokerage, and market-making services in equity and fixed income products consisting of foreign exchange and commodities; corporate and commercial real estate loans, which provides secured lending facilities and financing for sales and trading customers, as well as asset-backed and mortgage lending; and wealth management services, investment, and research services. The Wealth Management segment offers various financial services and solutions covering brokerage and investment advisory services; financial and wealth planning services; stock plan administration services; annuity and insurance products; securities-based lending, residential real estate loans, and other lending products; and banking and retirement plan services to individual investors and small to medium-sized businesses and institutions. The Investment Management segment provides various investment strategies and products comprising equity, fixed income, liquidity, and alternative/other products to benefit/defined contribution plans, foundations, endowments, government entities, sovereign wealth funds, insurance companies, and third-party fund sponsors and corporations through institutional and intermediary channels. The company was founded in 1924 and is headquartered in New York, New York.',
#  'city': 'New York',
#  'phone': '212-761-4000',
#  'state': 'NY',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.morganstanley.com',
#  'maxAge': 1,
#  'address1': '1585 Broadway',
#  'industry': 'Capital Markets',
#  'ebitdaMargins': 0,
#  'profitMargins': 0.25267,
#  'grossMargins': 0.89207,
#  'operatingCashflow': 8232000000,
#  'revenueGrowth': 0.259,
#  'operatingMargins': 0.39839,
#  'ebitda': None,
#  'targetLowPrice': None,
#  'recommendationKey': 'none',
#  'grossProfits': 42804000000,
#  'freeCashflow': None,
#  'targetMedianPrice': None,
#  'currentPrice': 99.87,
#  'earningsGrowth': 0.193,
#  'currentRatio': 1.912,
#  'returnOnAssets': 0.01381,
#  'numberOfAnalystOpinions': None,
#  'targetMeanPrice': None,
#  'debtToEquity': 328.485,
#  'returnOnEquity': 0.15045999,
#  'targetHighPrice': None,
#  'totalCash': 575172968448,
#  'totalDebt': 351869992960,
#  'totalRevenue': 58268999680,
#  'totalCashPerShare': 320.536,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 32.53,
#  'quickRatio': 1.667,
#  'recommendationMean': None,
#  'exchange': 'NYQ',
#  'shortName': 'Morgan Stanley',
#  'longName': 'Morgan Stanley',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MS',
#  'messageBoardId': 'finmb_472898',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': -0.603,
#  'beta3Year': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': 0.7827562,
#  'morningStarRiskRating': None,
#  'forwardEps': 151.67,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 1794409984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 54.563,
#  'sharesShort': 13850611,
#  'sharesPercentSharesOut': 0.0077,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.67466,
#  'netIncomeToCommon': 14240000000,
#  'trailingEps': 7.832,
#  'lastDividendValue': 0.7,
#  'SandP52WeekChange': 0.3230616,
#  'priceToBook': 1.8303612,
#  'heldPercentInsiders': 0.21256,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 1.45,
#  'sharesShortPreviousMonthDate': 1631664000,
#  'floatShares': 1413278855,
#  'beta': 1.545974,
#  'enterpriseValue': -35129077760,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 948931200,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1635379200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.364,
#  'priceToSalesTrailing12Months': 3.0755246,
#  'dateShortInterest': 1634256000,
#  'pegRatio': 0,
#  'ytdReturn': None,
#  'forwardPE': 0.6584691,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0098,
#  'sharesShortPriorMonth': 19016612,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 99.79,
#  'regularMarketOpen': 101.33,
#  'twoHundredDayAverage': 95.21478,
#  'trailingAnnualDividendYield': 0.021044191,
#  'payoutRatio': 0.2225,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 101.98,
#  'navPrice': None,
#  'averageDailyVolume10Day': 8517771,
#  'regularMarketPreviousClose': 99.79,
#  'fiftyDayAverage': 100.790855,
#  'trailingAnnualDividendRate': 2.1,
#  'open': 101.33,
#  'toCurrency': None,
#  'averageVolume10days': 8517771,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.8,
#  'exDividendDate': 1635379200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 99.725,
#  'currency': 'USD',
#  'trailingPE': 12.751533,
#  'regularMarketVolume': 8449640,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 179207733248,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 8005232,
#  'dayLow': 99.725,
#  'ask': 100.05,
#  'askSize': 1300,
#  'volume': 8449640,
#  'fiftyTwoWeekHigh': 105.95,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.26,
#  'fiftyTwoWeekLow': 54.9,
#  'bid': 99.9,
#  'tradeable': False,
#  'dividendYield': 0.027999999,
#  'bidSize': 1100,
#  'dayHigh': 101.98,
#  'regularMarketPrice': 99.87,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/morganstanley.com'}

# %%
yesterday = datetime.datetime.now() - datetime.timedelta(days=1)
yesterday.strftime('%Y-%m-%d')

try:
    try:
        df = pdr.get_data_yahoo(name, end = yesterday)
    except OverflowError           :
        print('Invalid Time!!! Return Default')
        df = pdr.get_data_yahoo(name, end=yesterday)
except KeyError:
    print('Not valid Stock')

# %%
df['ma5'] = df.loc[:, 'Close'].rolling(5).mean()
df['ma30'] = df.loc[:, 'Close'].rolling(30).mean()

def md(name, first_money, df):
    

    # data = data[:100]
    df = df[:]
    df[['Close', 'ma5', 'ma30']].plot()
    
    
    plt.show()
    
    
    sr1 = df['ma5'] < df['ma30']
    sr2 = df['ma5'] >= df['ma30']

    death_cross = df[sr1 & sr2.shift(1)].index  
    golden_cross = df[-(sr1 | sr2.shift(1))].index  


    
    money = first_money
    hold = 0   
    sr1 = pd.Series(1, index=golden_cross)
    sr2 = pd.Series(0, index=death_cross)
    sr = sr1.append(sr2)

    sr = sr.sort_index()

    for i in range(0, len(sr)):
        price = df['Open'][sr.index[i]]
        if sr.iloc[i] == 1:
            buy = money // (100 * price)

            hold += buy*100
            money -= buy*100*price
        else:
            money += hold * price
            hold = 0
    
    price = df['Open'][-1]
    now_money = hold * price + money
    print('earning: ', now_money - first_money)

# %%
first_money = 100000
md(name, first_money, df)
# Out:
# earning:  111814.02397155762

# %%
def get_CCI(df,N):
    '''
         Commodity Channel Index
     
principle:
     Use the current stock price volatility to compare with the normal distribution range to draw the conclusion of overbought or oversold, which is used to capture trend reversal points.
algorithm:
　 The difference between the typical price and the N-day moving average of the typical price divided by the average absolute deviation of the typical price in N days.
usage:
     When CCI is less than -100, it is a buy signal, and when CCI is greater than 100, it is a sell signal;
     When the stock price diverges, it is an obvious warning signal.
parameter:
     N　 sets the number of days for calculating the moving average, generally 14.'''
    
    
    
    df['typ']=(df['High']+df['Low']+df['Close'])/3
    
    df['CCI']=((df['typ']-df['typ'].rolling(N).mean())/
               (0.015*abs(df['typ']-df['typ'].rolling(N).mean()).rolling(N).mean()))
    return df

# %%
get_CCI(df,14)
df.tail(100)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-17   91.750000   87.059998   91.739998   87.910004  11131600.0
# 2021-06-18   86.900002   83.910004   86.389999   84.089996  22453900.0
# 2021-06-21   86.449997   84.220001   84.570000   85.940002  10672700.0
# 2021-06-22   86.220001   84.980003   85.860001   85.699997   9664100.0
# 2021-06-23   86.320000   85.570000   86.040001   85.870003   7139000.0
# ...                ...         ...         ...         ...         ...
# 2021-11-01  104.330002  102.690002  103.889999  104.000000   5432400.0
# 2021-11-02  105.339996  103.370003  103.930000  104.660004   7191700.0
# 2021-11-03  104.730003  101.879997  104.389999  102.610001   9009000.0
# 2021-11-04  102.309998   98.169998  102.230003   99.790001  14823800.0
# 2021-11-05  101.980003   99.730003  101.330002   99.870003   8447600.0
#
#              Adj Close         ma5        ma30         typ         CCI
# Date
# 2021-06-17   86.669785   90.496001   89.396333   88.906667  -80.731840
# 2021-06-18   82.903671   88.903999   89.305000   84.966667 -161.093547
# 2021-06-21   84.727577   87.948000   89.246333   85.536667 -131.322944
# 2021-06-22   84.490959   86.948000   89.220667   85.633334 -114.433624
# 2021-06-23   84.658562   85.902000   89.252333   85.920001  -95.344505
# ...                ...         ...         ...         ...         ...
# 2021-11-01  104.000000  102.924001  100.737334  103.673335   76.853212
# 2021-11-02  104.660004  103.162001  100.949334  104.456668   87.168804
# 2021-11-03  102.610001  103.310001  101.009668  103.073334   27.514257
# 2021-11-04   99.790001  102.768001  100.884334  100.089999  -79.811425
# 2021-11-05   99.870003  102.186002  100.783001  100.526670  -61.930873
#
# [100 rows x 10 columns]

# %%
df.loc[:, 'CCI'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#  Relative strength index
"""It analyzes the intention and strength of market orders by calculating the percentage of volatility caused by price increases to 
the total volatility through the average number of closing increases and decreases over a period of time."""



"""
RSI must be a number between 0 and 100. The larger the RSI value, the larger the proportion of the fluctuation caused 
by the price increase in the whole period of time. When the RSI exceeds 70, we believe that the increase is too strong, 
and then it is likely to reverse and fall, so the area above 70 is defined as an overbought area and should be sold. Conversely, 
we define the area below 30 as an oversold area and should be bought. Note that the threshold settings of 30 and 70 here are not absolute. According to different targets, 
different market conditions, and the risk appetite of different investors, it can be adjusted appropriately.
"""
def RSI(Close, period):

    
    Chg = Close - Close.shift(1)
    Chg_pos = pd.Series(index=Chg.index, data=Chg[Chg>0])
    Chg_pos = Chg_pos.fillna(0)
    Chg_neg = pd.Series(index=Chg.index, data=-Chg[Chg<0])
    Chg_neg = Chg_neg.fillna(0)
    

    import numpy as np
    up_mean = []
    down_mean = []
    for i in range(period+1, len(Chg_pos)+1):
        up_mean.append(np.mean(Chg_pos.values[i-period:i]))
        down_mean.append(np.mean(Chg_neg.values[i-period:i]))
    

    rsi = []
    for i in range(len(up_mean)):
        rsi.append( 100 * up_mean[i] / ( up_mean[i] + down_mean[i] ) )
    rsi_series = pd.Series(index = Close.index[period:], data = rsi)
    return rsi_series

# %%
rsi = RSI(df.loc[:, 'Close'], 14)

# %%
df['RSI'] = rsi

# %%
df.loc[:, 'RSI'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # common size B|S I|S and C|F

# %%
def common_size(bs, cf, i_s):
    csbs = bs.copy()
    csis = i_s.copy()
    cscf = cf.copy()

    for i, count in enumerate(csbs.loc['Total Assets', :]):
        csbs.iloc[:, i] = csbs.iloc[:, i]/ count
    for i, count in enumerate(csis.loc['Total Revenue', :]):
        csis.iloc[:, i] = csis.copy().iloc[:, i]/ count
        cscf.iloc[:, i] = cscf.iloc[:, i]/ count
    
    return csbs, csis, cscf

# %%
common_size_bs, common_size_is, common_size_cf  = common_size(bs, cf, i_s)

# %%
common_size_cf
# Out:
#                                            2021-09-30  2021-06-30  2021-03-31  \
# Investments                                 -0.578933    1.000745   -0.818754
# Change To Liabilities                        0.671863    0.450369    0.208029
# Total Cashflows From Investing Activities   -1.026706    0.211193   -1.435269
# Net Borrowings                               0.547279    0.484653    0.034353
# Total Cash From Financing Activities         0.798685    0.032861    0.608436
# Change To Operating Activities              -1.159696   -0.108002    1.048858
# Net Income                                   0.251271    0.237889    0.262103
# Change In Cash                              -0.177388    0.566570    0.792926
# Repurchase Of Stock                         -0.245916   -0.204485   -0.164260
# Effect Of Exchange Rate                     -0.093608    0.009825   -0.090209
# Total Cash From Operating Activities         0.144242    0.312691    1.709969
# Depreciation                                 0.070155    0.071617    0.056429
# Other Cashflows From Investing Activities   -0.014641   -0.012670   -0.002799
# Dividends Paid                              -0.091914   -0.050545   -0.048031
# Change To Account Receivables               -0.022504    1.108544   -1.190979
# Other Cashflows From Financing Activities    0.589236   -0.196761    0.786373
# Change To Netincome                          0.037755    0.042144    0.023729
# Capital Expenditures                        -0.041958   -0.034826   -0.033399
#
#                                            2020-12-31
# Investments                                  0.086290
# Change To Liabilities                        1.173387
# Total Cashflows From Investing Activities   -0.033724
# Net Borrowings                               0.644355
# Total Cash From Financing Activities         2.555645
# Change To Operating Activities              -2.237610
# Net Income                                   0.248167
# Change In Cash                               0.797801
# Repurchase Of Stock                         -0.003666
# Effect Of Exchange Rate                      0.137317
# Total Cash From Operating Activities        -1.861437
# Depreciation                                 0.103079
# Other Cashflows From Investing Activities   -0.040176
# Dividends Paid                              -0.053592
# Change To Account Receivables               -0.929326
# Other Cashflows From Financing Activities    1.968548
# Change To Netincome                         -0.007111
# Capital Expenditures                        -0.039516

# %%
bs
# Out:
#                              2021-09-30    2021-06-30    2021-03-31  \
# Intangible Assets          8.514000e+09  8.690000e+09  8.846000e+09
# Capital Surplus            2.850400e+10  2.803000e+10  2.740600e+10
# Total Liab                 1.083357e+12  1.053643e+12  1.051184e+12
# Total Stockholder Equity   9.815300e+10  9.912000e+10  9.850900e+10
# Minority Interest          1.216000e+09  1.292000e+09  1.329000e+09
# Other Current Liab         1.347870e+11  1.377870e+11  1.565780e+11
# Total Assets               1.190476e+12  1.161805e+12  1.158772e+12
# Common Stock               2.000000e+07  2.000000e+07  2.000000e+07
# Other Current Assets       1.226620e+11  1.200010e+11  1.268300e+11
# Retained Earnings          8.709900e+10  8.479100e+10  8.203400e+10
# Other Liab                 3.563810e+11  3.413620e+11  3.364100e+11
# Good Will                  1.683200e+10  1.683800e+10  1.683600e+10
# Treasury Stock            -1.747000e+10 -1.372100e+10 -1.095100e+10
# Other Assets               2.302200e+10  2.143100e+10  1.930800e+10
# Cash                       1.238630e+11  1.264800e+11  1.181180e+11
# Total Current Liabilities  5.001120e+11  4.991320e+11  5.187110e+11
# Short Long Term Debt       3.398000e+09  9.920000e+09  1.700400e+10
# Other Stockholder Equity  -2.701000e+09 -2.523000e+09 -2.754000e+09
# Total Current Assets       9.563790e+11  9.372380e+11  9.223120e+11
# Long Term Investments      1.857290e+11  1.776080e+11  1.914700e+11
# Net Tangible Assets        7.280700e+10  7.359200e+10  7.282700e+10
# Short Term Investments     2.456430e+11  2.226330e+11  2.168700e+11
# Net Receivables            2.585440e+11  2.549440e+11  2.579890e+11
# Long Term Debt             2.268640e+11  2.131490e+11  1.960630e+11
# Accounts Payable           2.403190e+11  2.338100e+11  2.301210e+11
# Property Plant Equipment            NaN           NaN           NaN
#
#                              2020-12-31
# Intangible Assets          4.980000e+09
# Capital Surplus            2.554600e+10
# Total Liab                 1.012713e+12
# Total Stockholder Equity   9.253100e+10
# Minority Interest          1.368000e+09
# Other Current Liab         1.311700e+11
# Total Assets               1.115862e+12
# Common Stock               2.000000e+07
# Other Current Assets       1.453910e+11
# Retained Earnings          7.869400e+10
# Other Liab                 3.125810e+11
# Good Will                  1.163500e+10
# Treasury Stock            -1.172900e+10
# Other Assets               1.491300e+10
# Cash                       1.056540e+11
# Total Current Liabilities  5.030470e+11
# Short Long Term Debt       2.619900e+10
# Other Stockholder Equity  -1.962000e+09
# Total Current Assets       8.953510e+11
# Long Term Investments      1.845640e+11
# Net Tangible Assets        7.591600e+10
# Short Term Investments     2.286250e+11
# Net Receivables            2.350870e+11
# Long Term Debt             1.925990e+11
# Accounts Payable           2.274370e+11
# Property Plant Equipment   4.419000e+09

# %%
i_s
# Out:
#                                            2021-09-30     2021-06-30  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        4874000000.0   4566000000.0
# Minority Interest                        1216000000.0   1292000000.0
# Net Income                               3707000000.0   3511000000.0
# Selling General Administrative           7227000000.0   7704000000.0
# Gross Profit                            13140000000.0  13199000000.0
# Ebit                                              0.0            0.0
# Operating Income                         5889000000.0   5422000000.0
# Other Operating Expenses                         None           None
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       1150000000.0   1054000000.0
# Total Revenue                           14753000000.0  14759000000.0
# Total Operating Expenses                 8864000000.0   9337000000.0
# Cost Of Revenue                          1613000000.0   1560000000.0
# Total Other Income Expense Net          -1015000000.0   -856000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           3724000000.0   3512000000.0
# Net Income Applicable To Common Shares   3584000000.0   3408000000.0
#
#                                            2021-03-31     2020-12-31
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        5344000000.0   4430000000.0
# Minority Interest                        1329000000.0   1368000000.0
# Net Income                               4120000000.0   3385000000.0
# Selling General Administrative           7940000000.0   6595000000.0
# Gross Profit                            14076000000.0  12167000000.0
# Ebit                                              0.0            0.0
# Operating Income                         6234000000.0   5572000000.0
# Other Operating Expenses                         None           None
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       1176000000.0   1018000000.0
# Total Revenue                           15719000000.0  13640000000.0
# Total Operating Expenses                 9485000000.0   8068000000.0
# Cost Of Revenue                          1643000000.0   1473000000.0
# Total Other Income Expense Net           -890000000.0  -1142000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           4168000000.0   3412000000.0
# Net Income Applicable To Common Shares   3982000000.0   3266000000.0

# %%
cf
# Out:
#                                              2021-09-30    2021-06-30  \
# Investments                               -8.541000e+09  1.477000e+10
# Change To Liabilities                      9.912000e+09  6.647000e+09
# Total Cashflows From Investing Activities -1.514700e+10  3.117000e+09
# Net Borrowings                             8.074000e+09  7.153000e+09
# Total Cash From Financing Activities       1.178300e+10  4.850000e+08
# Change To Operating Activities            -1.710900e+10 -1.594000e+09
# Net Income                                 3.707000e+09  3.511000e+09
# Change In Cash                            -2.617000e+09  8.362000e+09
# Repurchase Of Stock                       -3.628000e+09 -3.018000e+09
# Effect Of Exchange Rate                   -1.381000e+09  1.450000e+08
# Total Cash From Operating Activities       2.128000e+09  4.615000e+09
# Depreciation                               1.035000e+09  1.057000e+09
# Other Cashflows From Investing Activities -2.160000e+08 -1.870000e+08
# Dividends Paid                            -1.356000e+09 -7.460000e+08
# Change To Account Receivables             -3.320000e+08  1.636100e+10
# Other Cashflows From Financing Activities  8.693000e+09 -2.904000e+09
# Change To Netincome                        5.570000e+08  6.220000e+08
# Capital Expenditures                      -6.190000e+08 -5.140000e+08
#
#                                              2021-03-31    2020-12-31
# Investments                               -1.287000e+10  1.177000e+09
# Change To Liabilities                      3.270000e+09  1.600500e+10
# Total Cashflows From Investing Activities -2.256100e+10 -4.600000e+08
# Net Borrowings                             5.400000e+08  8.789000e+09
# Total Cash From Financing Activities       9.564000e+09  3.485900e+10
# Change To Operating Activities             1.648700e+10 -3.052100e+10
# Net Income                                 4.120000e+09  3.385000e+09
# Change In Cash                             1.246400e+10  1.088200e+10
# Repurchase Of Stock                       -2.582000e+09 -5.000000e+07
# Effect Of Exchange Rate                   -1.418000e+09  1.873000e+09
# Total Cash From Operating Activities       2.687900e+10 -2.539000e+10
# Depreciation                               8.870000e+08  1.406000e+09
# Other Cashflows From Investing Activities -4.400000e+07 -5.480000e+08
# Dividends Paid                            -7.550000e+08 -7.310000e+08
# Change To Account Receivables             -1.872100e+10 -1.267600e+10
# Other Cashflows From Financing Activities  1.236100e+10  2.685100e+10
# Change To Netincome                        3.730000e+08 -9.700000e+07
# Capital Expenditures                      -5.250000e+08 -5.390000e+08

# %% [markdown]
# ## stock combination

# %%
stock_name_list = ["MS","MSFT","AMZN","TSLA","GS"]

# %%
all_stocks = stock_name_list

# %%
all_dfs = yf.download(all_stocks, end = yesterday).loc[:, 'Close']
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
all_dfs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
all_dfs
# Out:
#                    AMZN          GS          MS        MSFT         TSLA
# Date
# 1986-03-13          NaN         NaN         NaN    0.097222          NaN
# 1986-03-14          NaN         NaN         NaN    0.100694          NaN
# 1986-03-17          NaN         NaN         NaN    0.102431          NaN
# 1986-03-18          NaN         NaN         NaN    0.099826          NaN
# 1986-03-19          NaN         NaN         NaN    0.098090          NaN
# ...                 ...         ...         ...         ...          ...
# 2021-11-01  3318.110107  416.700012  104.000000  329.369995  1208.589966
# 2021-11-02  3312.750000  423.850006  104.660004  333.130005  1172.000000
# 2021-11-03  3384.000000  417.899994  102.610001  334.000000  1213.859985
# 2021-11-04  3477.000000  408.070007   99.790001  336.440002  1229.910034
# 2021-11-05  3518.989990  407.079987   99.870003  336.059998  1222.089966
#
# [8988 rows x 5 columns]

# %%
log_returns = np.log(all_dfs.pct_change()+1)

# %%
log_returns.mean()*252
# Out:
# AMZN    0.306516
# GS      0.078063
# MS      0.089095
# MSFT    0.228475
# TSLA    0.488518
# dtype: float64

# %%
port_returns = []
port_variance = []
for p in range(1000):
    weights = np.random.random(len(all_stocks))
    weights /=np.sum(weights)
    port_returns.append(np.sum(log_returns.mean()*252*weights))
    port_variance.append(np.sqrt(np.dot(weights.T, np.dot(log_returns.cov()*252, weights))))

port_returns = np.array(port_returns)
port_variance = np.array(port_variance)


risk_free = 0.03
plt.figure(figsize=(8, 6))
plt.scatter(port_variance, port_returns, c=(port_returns-risk_free)/port_variance, marker = 'o')
plt.grid(True)
plt.xlabel('Expected Volatility')
plt.ylabel('Expected Return')
plt.colorbar(label = 'Sharpe Ratio')

# %%
def stats(weights):
    weights = np.array(weights)
    port_returns = np.sum(log_returns.mean()*weights)*252
    port_variance = np.sqrt(np.dot(weights.T, np.dot(log_returns.cov()*252,weights)))
    return np.array([port_returns, port_variance, port_returns/port_variance])


def min_sharpe(weights):
    return -stats(weights)[2]


x0 = 5*[1./5]

bnds = tuple((0,1) for x in range(len(all_stocks)))


cons = ({'type':'eq', 'fun':lambda x: np.sum(x)-1})

opts = sco.minimize(min_sharpe,
                    x0, 
                    method = 'SLSQP', 
                    bounds = bnds, 
                    constraints = cons)
opts
# Out:
#      fun: -1.0250220651641009
#      jac: array([-1.38163567e-04,  2.06768557e-01,  2.76806861e-01,  4.60296869e-05,
#         7.77840614e-06])
#  message: 'Optimization terminated successfully'
#     nfev: 43
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([1.57166494e-01, 2.77555756e-17, 0.00000000e+00, 3.96627559e-01,
#        4.46205947e-01])

# %%
#Portfolio optimization 2-minimum variance

def min_variance(weights):
    return stats(weights)[1]

optv = sco.minimize(min_variance, 
                    x0, 
                    method = 'SLSQP', 
                    bounds = bnds, 
                    constraints = cons)
optv
# Out:
#      fun: 0.28657762493632144
#      jac: array([0.28685839, 0.2866249 , 0.32147117, 0.28652719, 0.28649785])
#  message: 'Optimization terminated successfully'
#     nfev: 48
#      nit: 8
#     njev: 8
#   status: 0
#  success: True
#        x: array([6.29341773e-02, 3.43769884e-01, 3.43692089e-17, 4.57078640e-01,
#        1.36217299e-01])

# %%
def min_variance(weights):
    return stats(weights)[1]

target_returns = np.linspace(0.0,0.5,50)
target_variance = []
for tar in target_returns:
    cons = ({'type':'eq','fun':lambda x:stats(x)[0]-tar},{'type':'eq','fun':lambda x:np.sum(x)-1})
    res = sco.minimize(min_variance, x0, method = 'SLSQP', bounds = bnds, constraints = cons)
    target_variance.append(res['fun'])

target_variance = np.array(target_variance)

# %%
plt.figure(figsize = (8,4))

plt.scatter(port_variance, port_returns, c = port_returns/port_variance,marker = 'o')

plt.scatter(target_variance,target_returns, c = target_returns/target_variance, marker = 'x')

plt.plot(stats(opts['x'])[1], stats(opts['x'])[0], 'r*', markersize = 15.0)

plt.plot(stats(optv['x'])[1], stats(optv['x'])[0], 'y*', markersize = 15.0)

plt.grid(True)
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label = 'Sharpe ratio')
